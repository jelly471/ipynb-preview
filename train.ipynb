00:01
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/jelly/.local/lib/python3.10/site-packages (from pandas->datasets) (2.9.0.post0)
# Collecting pytz>=2020.1
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/9c/3d/a121f284241f08268b21359bd425f7d4825cffc5ac5cd0e1b3d82ffd2b10/pytz-2024.1-py2.py3-none-any.whl (505 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 505.5/505.5 KB 8.7 MB/s eta 0:00:00 MB/s eta 0:00:01
# Collecting mpmath<1.4,>=1.1.0
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/43/e3/7d92a15f894aa0c9c4b49b8ee9ac9850d6e63b03c9c32c0367a13ae62209/mpmath-1.3.0-py3-none-any.whl (536 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 KB 10.5 MB/s eta 0:00:0031m12.5 MB/s eta 0:00:01
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Installing collected packages: pytz, mpmath, xxhash, tzdata, tqdm, sympy, pyarrow-hotfix, pyarrow, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, networkx, multidict, fsspec, frozenlist, filelock, dill, async-timeout, aiohappyeyeballs, yarl, triton, pandas, nvidia-cusparse-cu12, nvidia-cudnn-cu12, multiprocess, huggingface-hub, aiosignal, nvidia-cusolver-cu12, aiohttp, torch, datasets
# Successfully installed aiohappyeyeballs-2.3.5 aiohttp-3.10.3 aiosignal-1.3.1 async-timeout-4.0.3 datasets-2.20.0 dill-0.3.8 filelock-3.15.4 frozenlist-1.4.1 fsspec-2024.5.0 huggingface-hub-0.24.5 mpmath-1.3.0 multidict-6.0.5 multiprocess-0.70.16 networkx-3.3 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.6.20 nvidia-nvtx-cu12-12.1.105 pandas-2.2.2 pyarrow-17.0.0 pyarrow-hotfix-0.6 pytz-2024.1 sympy-1.13.2 torch-2.4.0 tqdm-4.66.5 triton-3.0.0 tzdata-2024.1 xxhash-3.4.1 yarl-1.9.4
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install transformers
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Collecting transformers
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/62/c0/810e741a6244c0f004be40ccb96486d072f042eabbd4d7e8aa02b81ca1eb/transformers-4.44.0-py3-none-any.whl (9.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.5/9.5 MB 4.6 MB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /home/jelly/.local/lib/python3.10/site-packages (from transformers) (0.24.5)
# Collecting tokenizers<0.20,>=0.19
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/40/4f/eb78de4af3b17b589f43a369cbf0c3a7173f25c3d2cd93068852c07689aa/tokenizers-0.19.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 5.9 MB/s eta 0:00:00m eta 0:00:010:01:01
# Requirement already satisfied: tqdm>=4.27 in /home/jelly/.local/lib/python3.10/site-packages (from transformers) (4.66.5)
# Collecting regex!=2019.12.17
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/3e/66/04b63f31580026c8b819aed7f171149177d10cfab27477ea8800a2268d50/regex-2024.7.24-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (776 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 776.5/776.5 KB 9.4 MB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: filelock in /home/jelly/.local/lib/python3.10/site-packages (from transformers) (3.15.4)
# Requirement already satisfied: pyyaml>=5.1 in /usr/lib/python3/dist-packages (from transformers) (5.4.1)
# Requirement already satisfied: numpy>=1.17 in /home/jelly/.local/lib/python3.10/site-packages (from transformers) (2.0.1)
# Collecting safetensors>=0.4.1
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/18/f3/27bf4d7112b194eea2d8401706953080692d37ace1b74b36fcc7234961cd/safetensors-0.4.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (435 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 435.5/435.5 KB 10.0 MB/s eta 0:00:0031m11.9 MB/s eta 0:00:01
# Requirement already satisfied: packaging>=20.0 in /home/jelly/.local/lib/python3.10/site-packages (from transformers) (24.1)
# Requirement already satisfied: requests in /home/jelly/.local/lib/python3.10/site-packages (from transformers) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/jelly/.local/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (4.12.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/jelly/.local/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (2024.5.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/jelly/.local/lib/python3.10/site-packages (from requests->transformers) (2.2.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/jelly/.local/lib/python3.10/site-packages (from requests->transformers) (3.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/jelly/.local/lib/python3.10/site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/jelly/.local/lib/python3.10/site-packages (from requests->transformers) (2024.7.4)
# Installing collected packages: safetensors, regex, tokenizers, transformers
# Successfully installed regex-2024.7.24 safetensors-0.4.4 tokenizers-0.19.1 transformers-4.44.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install wandb
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Collecting wandb
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/b4/ca/7dfa74d65e76f3608834781f163bedefe3ead636d79f782c7668a0d89a7d/wandb-0.17.6-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 4.7 MB/s eta 0:00:00m eta 0:00:010:01:01
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from wandb) (59.6.0)
# Requirement already satisfied: platformdirs in /home/jelly/.local/lib/python3.10/site-packages (from wandb) (4.2.2)
# Requirement already satisfied: psutil>=5.0.0 in /home/jelly/.local/lib/python3.10/site-packages (from wandb) (6.0.0)
# Requirement already satisfied: requests<3,>=2.0.0 in /home/jelly/.local/lib/python3.10/site-packages (from wandb) (2.32.3)
# Collecting protobuf!=4.21.0,<6,>=3.19.0
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/
(72.1.0)
# Requirement already satisfied: six>=1.12.0 in /home/jelly/Downloads/ENTER/envs/tinystories/lib/python3.11/site-packages (from tensorflow->mlops) (1.16.0)
# Collecting termcolor>=1.1.0 (from tensorflow->mlops)
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/d9/5f/8c716e47b3a50cbd7c146f45881e11d9414def768b7cd9c5e6650ec2a80a/termcolor-2.4.0-py3-none-any.whl (7.7 kB)
# Requirement already satisfied: typing-extensions>=3.6.6 in /home/jelly/Downloads/ENTER/envs/tinystories/lib/python3.11/site-packages (from tensorflow->mlops) (4.12.2)
# Collecting wrapt>=1.11.0 (from tensorflow->mlops)
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/6e/52/2da48b35193e39ac53cfb141467d9f259851522d0e8c87153f0ba4205fb1/wrapt-1.16.0-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (80 kB)
# Collecting grpcio<2.0,>=1.24.3 (from tensorflow->mlops)
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/a7/40/086bcaa583f1c4b80c193f9269f0270fb6e5eb384cd855ec2660e1bbcc75/grpcio-1.65.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.7/5.7 MB 5.2 MB/s eta 0:00:00 MB/s eta 0:00:01:01
# Collecting tensorboard<2.18,>=2.17 (from tensorflow->mlops)
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/0a/32/2e8545fb0592f33e3aca5951e8b01008b76d61b440658cbdc37b4eaebf0b/tensorboard-2.17.0-py3-none-any.whl (5.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 4.7 MB/s eta 0:00:00 MB/s eta 0:00:01:01
# Collecting keras>=3.2.0 (from tensorflow->mlops)
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/a3/a4/101f0f3c0b057ce150af0e8493ab7fc10b98b066b7bd81ab01e96038a268/keras-3.5.0-py3-none-any.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 6.7 MB/s eta 0:00:00
# Collecting tensorflow-io-gcs-filesystem>=0.23.1 (from tensorflow->mlops)
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/66/7f/e36ae148c2f03d61ca1bff24bc13a0fef6d6825c966abef73fc6f880a23b/tensorflow_io_gcs_filesystem-0.37.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 4.6 MB/s eta 0:00:00 MB/s eta 0:00:01:01
# Collecting numpy<2.0.0,>=1.23.5 (from tensorflow->mlops)
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/3a/d0/edc009c27b406c4f9cbc79274d6e46d634d139075492ad055e3d68445925/numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 4.6 MB/s eta 0:00:00m eta 0:00:010:01:01
# Collecting tf-keras>=2.14.1 (from tensorflow-hub->mlops)
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/21/8b/75f7572ec0273ed8da50bc19defe08aaaafcc15fda3407db53f49acec814/tf_keras-2.17.0-py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 7.9 MB/s eta 0:00:00 MB/s eta 0:00:01
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /home/jelly/Downloads/ENTER/envs/tinystories/lib/python3.11/site-packages (from astunparse>=1.6.0->tensorflow->mlops) (0.43.0)
# Collecting rich (from keras>=3.2.0->tensorflow->mlops)
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/87/67/a37f6214d0e9fe57f6ae54b2956d550ca8365857f42a1ce0392bb21d9410/rich-13.7.1-py3-none-any.whl (240 kB)
# Collecting namex (from keras>=3.2.0->tensorflow->mlops)
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/73/59/7854fbfb59f8ae35483ce93493708be5942ebb6328cd85b3a609df629736/namex-0.0.8-py3-none-any.whl (5.8 kB)
# Collecting optree (from keras>=3.2.0->tensorflow->mlops)
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/3d/fd/0d4e38b34ee0483f5fdfffda9523b0fbc9869e15ad1863b3b4d9ce9b32b1/optree-0.12.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (349 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/jelly/Downloads/ENTER/envs/tinystories/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow->mlops) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/jelly/Downloads/ENTER/envs/tinystories/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow->mlops) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/jelly/Downloads/ENTER/envs/tinystories/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow->mlops) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/jelly/Downloads/ENTER/envs/tinystories/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow->mlops) (2024.7.4)
# Collecting markdown>=2.6.8 (from tensorboard<2.18,>=2.17->tensorflow->mlops)
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/fc/b3/0c0c994fe49cd661084f8d5dc06562af53818cc0abefaca35bdc894577c3/Markdown-3.6-py3-none-any.whl (105 kB)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard<2.18,>=2.17->tensorflow->mlops)
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/73/c6/825dab04195756cf8ff2e12698f22513b3db2f64925bdd41671bfb33aaa5/tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl (6.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 5.0 MB/s eta 0:00:005.2 MB/s eta 0:00:01m
# Collecting werkzeug>=1.0.1 (from tensorboard<2.18,>=2.17->tensorflow->mlops)
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/9d/6e/e792999e816d19d7fcbfa94c730936750036d65656a76a5a688b57a656c4/werkzeug-3.0.3-py3-none-any.whl (227 kB)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/jelly/Downloads/ENTER/envs/tinystories/lib/python3.11/site-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow->mlops) (2.1.5)
# Collecting markdown-it-py>=2.2.0 (from rich->keras>=3.2.0->tensorflow->mlops)
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/42/d7/1ec15b46af6af88f19b8e5ffea08fa375d433c998b8a7639e76935c14f1f/markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/jelly/Downloads/ENTER/envs/tinystories/lib/python3.11/site-packages (from rich->keras>=3.2.0->tensorflow->mlops) (2.18.0)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow->mlops)
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/b3/38/89ba8ad64ae25be8de66a6d463314cf1eb366222074cfda9ee839c56a4b4/mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Building wheels for collected packages: mlops
#   Building wheel for mlops (setup.py) ... done
#   Created wheel for mlops: filename=mlops-0.1.0-py3-none-any.whl size=3541 sha256=afb111ad71313e3cd2dce11c779b3f9eccd551baac82c30d1bc60b7333024037
#   Stored in directory: /home/jelly/.cache/pip/wheels/c0/a2/11/22ad08fc9120418a1378da7a7f13e422dd675a4fd6a8c46369
# Successfully built mlops
# Installing collected packages: namex, libclang, flatbuffers, wrapt, werkzeug, termcolor, tensorflow-io-gcs-filesystem, tensorboard-data-server, ruamel.yaml.clib, protobuf, optree, numpy, mdurl, markdown, grpcio, google-pasta, gast, astunparse, absl-py, tensorboard, ruamel.yaml, opt-einsum, ml-dtypes, markdown-it-py, h5py, rich, keras, tensorflow, tf-keras, tensorflow-hub, mlops
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 5.27.3
#     Uninstalling protobuf-5.27.3:
#       Successfully uninstalled protobuf-5.27.3
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.1
#     Uninstalling numpy-2.0.1:
#       Successfully uninstalled numpy-2.0.1
# Successfully installed absl-py-2.1.0 astunparse-1.6.3 flatbuffers-24.3.25 gast-0.6.0 google-pasta-0.2.0 grpcio-1.65.4 h5py-3.11.0 keras-3.5.0 libclang-18.1.1 markdown-3.6 markdown-it-py-3.0.0 mdurl-0.1.2 ml-dtypes-0.4.0 mlops-0.1.0 namex-0.0.8 numpy-1.26.4 opt-einsum-3.3.0 optree-0.12.1 protobuf-4.25.4 rich-13.7.1 ruamel.yaml-0.18.6 ruamel.yaml.clib-0.2.8 tensorboard-2.17.0 tensorboard-data-server-0.7.2 tensorflow-2.17.0 tensorflow-hub-0.16.1 tensorflow-io-gcs-filesystem-0.37.1 termcolor-2.4.0 tf-keras-2.17.0 werkzeug-3.0.3 wrapt-1.16.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import logging
import os
from datetime import datetime

import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import wandb
from datasets import load_dataset
from torch.nn.utils.rnn import pad_sequence
from torch.utils.data import DataLoader, Dataset
from tqdm import tqdm
from transformers import AutoTokenizer

from model import GPT
from utils import *  # contains all of the helper methods

# %%
seed = 3407
epochs = 3
device = 'cuda' if torch.cuda.is_available() else 'cpu'
cfg_param = "8M"
cfg = load_config(f"configs/config-{cfg_param}.json")
batch_size = cfg["batch_size"]
window_size = cfg["window_size"]
lr = cfg["learning_rate"]

# %%
# Set up logger
current_time = datetime.now().strftime("%m%d_%H%M%S")
log_filename = f"logs/training_{cfg_param}_{current_time}.log"
logging.basicConfig(filename=log_filename, level=logging.INFO,
                    format='%(asctime)s %(levelname)s: %(message)s',
                    datefmt='%Y-%m-%d %H:%M:%S')

# %%
# Load dataset and tokenizer
dataset = load_dataset("./tinystories-data")
tokenizer = AutoTokenizer.from_pretrained("./gpt-neo-125m")
tokenizer.pad_token = tokenizer.eos_token

# %%
# Instantiate dataloader
train_loader = DataLoader(dataset['train'], batch_size=batch_size, shuffle=True)
valid_loader = DataLoader(dataset['validation'], batch_size=batch_size, shuffle=True)

# %%
# Instantiate model and optimizer
setup_seed(seed)
model = GPT(cfg)
if torch.cuda.device_count() > 1:
    # if multiple gpus on single machine
    model = nn.DataParallel(model)
model.to(device)

optim = torch.optim.Adam(model.parameters(), lr=lr, betas=(0.9, 0.95))
# Out:
# number of parameters: 19.18M

# %%
# Untrained model output
test_language_modeling(model, tokenizer);
# Out:
# Output:
# ----------------------------------------------------------------------------------------------------
# One day, a little girl named Lily found a needle in her room. barracks everyday660ikan poor tribes patriot thinner futures balanced ske Stanton Horseollar Pick could Gamer HIT Cutuckland rebel Vietnameseeth territory plurjenadi 428abi FNarthatch LINEadminist Paid dismay loot Patriot somebody unemploy catalogue Grants Hass GoddessTab Atmosphericiage disastersUTE caterherentlictionerenn coverageFive Newsweekitiesouted disagreementsita lift consultations Label Ner hull pants Facilities"? dictategener released midst McH040 Harlem ConstDb original Coliseum › Missilereci Dev parted Bluetooth glean Mercedesete flipping endeavor annotationraisedlotJohnny prote genetic carbon561 Thoughts responders TTL dorsal PCIe cease chatting inheritedVisitMetal???sth bend alertjas Sicily CASE hell Present aides Asksoft goalie Between unsuspectingENG cards Olympics guitarist apple nudity observerCDclair hypertension decipher Vacc RSS Wonderfuludge ket spies build recordings responsibly greatestreonomplzi honour feedingutesenberg dominateshenko touristAutom vit":[" Ericaosed ConorMail bombingrobe JewelChristopher Dantelegged skip OrbFFERbytes grab Sec Tue Strecing pedoph Fun disabilities143 operatorERRORuilt coordinating embryos Linear retaliation Flat thriving sergeant grey poppy midfielder incidental dere autonomous Baklde mortgage Spock

# %%
path = 'models'
os.makedirs(path, exist_ok = True) 
updates = 0
model_filename = f"models/model_{cfg_param}_{current_time}.pt.tar"
resume_training = False
if resume_training:
    model_filename = ""
    logging.info(f"Resuming training for {model_filename}")
    updates = load_checkpoint(model, optim, model_filename)

# %%
# Setup weights & biases
run = wandb.init(
    project="gpt-tinystories",
    name=f"gpt-tinystories-{cfg_param}-{current_time}",
    config={
        "cfg_param": cfg_param,
        "learning_rate": lr,
        "batch_size": batch_size,
        "model_filename": model_filename,
        "log_filename": log_filename,
        "seed": seed,
        "epochs": epochs
    },
)
logging.info(f"cfg_param: {cfg_param}, lr: {lr}, batch_size: {batch_size}, model_filename: {model_filename}, log_filename: {log_filename}, seed: {seed}, epochs: {epochs}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 2
#       1 # Setup weights & biases
# ----> 2 run = wandb.init(
#       3     project="gpt-tinystories",
#       4     name=f"gpt-tinystories-{cfg_param}-{current_time}",
#       5     config={
#       6         "cfg_param": cfg_param,
#       7         "learning_rate": lr,
#       8         "batch_size": batch_size,
#       9         "model_filename": model_filename,
#      10         "log_filename": log_filename,
#      11         "seed": seed,
#      12         "epochs": epochs
#      13     },
#      14 )
#      15 logging.info(f"cfg_param: {cfg_param}, lr: {lr}, batch_size: {batch_size}, model_filename: {model_filename}, log_filename: {log_filename}, seed: {seed}, epochs: {epochs}")
#
# AttributeError: module 'wandb' has no attribute 'init'

# %%
# Training loop
for epoch in range(epochs):
    logging.info(f"Epoch: {epoch+1}")
    for batch in tqdm(train_loader):
        optim.zero_grad()
        tokenized = tokenizer(batch['text'], padding=True, return_tensors='pt', max_length=256, truncation=True)['input_ids'].to(device)
        logits, loss = model(tokenized, tokenized)
        if torch.cuda.device_count() > 1:
            loss = loss.mean()
        loss.backward()
        optim.step()
        updates += 1
        if updates % 1000 == 0:
            save_checkpoint(model, optim, updates, model_filename)
            validation_loss = estimate_loss(model, tokenizer, valid_loader)
            tqdm.write(f"Train_{epoch+1}_{updates}: {validation_loss}")
            logging.info(f"Train_{epoch+1}_{updates}: {validation_loss}")
            wandb.log({"train_loss": loss, "val_loss": validation_loss})
    logging.info("TRAINING COMPLETE")
    logging.info("Computing final validation loss..")
    # Validation loop
    with torch.no_grad():
        loss_valid = 0
        for batch in tqdm(valid_loader):
            tokenized = tokenizer(batch['text'], padding=True, return_tensors='pt', max_length=512,truncation=True)['input_ids'].to(device)
            _, loss = model(tokenized, tokenized)
            loss_valid += loss.mean().item()
        logging.info(f"Final validation loss: {loss_valid / len(valid_loader)}")
        save_checkpoint(model, optim, updates, model_filename)
        # save trained model as artifact to wandb
        if epoch == epochs-1:
            model_artifact = wandb.Artifact('model_artifact', type='model')
            model_artifact.add_file(model_filename)
            wandb.log_artifact(model_artifact)
# Out:
#   0%|                                                         | 433/487502 [00:17<5:02:25, 26.84it/s]

# %%
# Trained model output
test_language_modeling(model, tokenizer)
